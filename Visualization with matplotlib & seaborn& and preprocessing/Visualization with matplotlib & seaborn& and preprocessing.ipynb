# %%
import seaborn as sns
import pandas as pd
sns.set(rc={'figure.figsize':[8,8]},font_scale=1.2)

# %%
df = pd.read_csv('./50ulke.csv',sep=",")

# %%
df.head()
# Out:
#    Unnamed: 0       Countries  National Income  Growth  Per person  \
# 0           0   United States         20412.87    2.27       62152
# 1           1           China         14092.51    6.86       10088
# 2           2           Japan          5167.05    1.71       40849
# 3           3         Germany          4211.64    2.51       50842
# 4           4  United Kingdom          2936.29    1.79       44177
#
#        Continent
# 0  North America
# 1           Asia
# 2           Asia
# 3         Europe
# 4         Europe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       50 non-null     int64
#  1   Countries        50 non-null     object
#  2   National Income  50 non-null     float64
#  3   Growth           50 non-null     float64
#  4   Per person       50 non-null     int64
#  5   Continent        50 non-null     object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  National Income     Growth    Per person
# count    50.00000        50.000000  50.000000     50.000000
# mean     24.50000      1646.348200   3.320400  27696.000000
# std      14.57738      3448.554429   2.053468  25094.131496
# min       0.00000       231.570000  -0.740000   1615.000000
# 25%      12.25000       353.440000   1.795000   6402.000000
# 50%      24.50000       522.985000   2.880000  14565.500000
# 75%      36.75000      1504.895000   4.287500  48738.250000
# max      49.00000     20412.870000   7.810000  86835.000000

# %%
df['National Income'].hist(color='g')
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(df['National Income'], color='g')
# Out:
# <AxesSubplot:xlabel='National Income', ylabel='Density'>

# %%
df['Growth'].hist(color='g')
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(df['Growth'], color='g')
# Out:
# <AxesSubplot:xlabel='Growth', ylabel='Density'>

# %%
df['Per person'].hist(color='g')
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(df['Per person'],color='g')
# Out:
# <AxesSubplot:xlabel='Per person', ylabel='Density'>

# %%
sns.regplot(x=df['Growth'],y=df['National Income'],color='g')
# Out:
# <AxesSubplot:xlabel='Growth', ylabel='National Income'>

# %%
sns.regplot(x=df['Per person'],y=df['National Income'],color='g')
# Out:
# <AxesSubplot:xlabel='Per person', ylabel='National Income'>

# %%
sns.regplot(x=df['Growth'],y=df['Per person'],color='g')
# Out:
# <AxesSubplot:xlabel='Growth', ylabel='Per person'>

# %%
sns.jointplot(x='Growth', y='National Income', data=df, kind='scatter',height=8,color='g')

# %%
sns.jointplot(x='Per person', y='National Income', data=df, kind='scatter',height=8,color='g')

# %%
sns.jointplot(x='Growth', y='Per person', data=df, kind='scatter',height=8,color='g')

# %%
sns.pairplot(df, vars=['National Income', 'Growth','Per person'],height=3, aspect=1.3)

# %%
sns.pairplot(df, vars=['National Income', 'Growth','Per person'],hue='Continent',height=3, aspect=1.3)
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(df['National Income'],color='g')
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='National Income'>

# %%
sns.boxplot(df['Growth'],color='g')
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Growth'>

# %%
sns.boxplot(df['Per person'],color='g')
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Per person'>

# %%
sns.boxplot(x='Continent',y='National Income',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='National Income'>

# %%
sns.boxplot(x='Continent',y='Growth',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.boxplot(x='Continent',y='Per person',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Per person'>

# %%
sns.violinplot(x='Continent',y='National Income',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='National Income'>

# %%
sns.violinplot(x='Continent',y='Growth',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.violinplot(x='Continent',y='Per person',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Per person'>

# %%
sns.stripplot(x='Continent',y='National Income',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='National Income'>

# %%
sns.stripplot(x='Continent',y='Growth',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.stripplot(x='Continent',y='Per person',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Per person'>

# %%
sns.swarmplot(x='Continent',y='National Income',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='National Income'>

# %%
sns.swarmplot(x='Continent',y='Growth',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.swarmplot(x='Continent',y='Per person',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Per person'>

# %%
sns.barplot(x='Continent',y='National Income',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='National Income'>

# %%
sns.barplot(x='Continent',y='Growth',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Growth'>

# %%
sns.barplot(x='Continent',y='Per person',data=df)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Per person'>

# %%
df.corr()
# Out:
#                  Unnamed: 0  National Income    Growth  Per person
# Unnamed: 0         1.000000        -0.549732  0.261063   -0.273373
# National Income   -0.549732         1.000000  0.008961    0.159121
# Growth             0.261063         0.008961  1.000000   -0.252786
# Per person        -0.273373         0.159121 -0.252786    1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
